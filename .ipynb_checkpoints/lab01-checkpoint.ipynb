# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd
import sklearn

RANDOM_STATE = 42
DATA_PATH = Path('data/dataset.xlsm')

print(sys.version)
print('pandas:', pd.__version__)
print('scikit-learn:', sklearn.__version__)
# Out:
# 3.11.16 (main, Aug 13 2026, 09:46:36) [GCC 15.2.0]
# pandas: 2.2.2
# scikit-learn: 1.4.2
